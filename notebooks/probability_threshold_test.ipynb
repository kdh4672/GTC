# %%
from operator import is_
import os
import sys

import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
import numpy as np

import clip
sys.path.append("../")
from Metrics import base_kmeans_model_evaluation, kmeans_with_init, cosine_kmeans_with_init
from networks import CustomCLIP, load_clip_to_cpu
from lr_scheduler import ConstantWarmupScheduler

import argparse

# parser
clip_backbone="ViT-L/14"
batch_size=50
total_epoch=5
lr=3e-4
scheduler_operate=False
repeat=4
is_test_dataset = False
cosine_sim=True
n_ctx=16
total_dpoch = repeat
# parser

print(clip.available_models())
device = torch.device('cuda') if torch.cuda.is_available() else "cpu"
print('Device:', device)
print('Current cuda device:', torch.cuda.current_device())
print('Count of using GPUs:', torch.cuda.device_count())

backbone_name = clip_backbone
clip_model, preprocess = load_clip_to_cpu(backbone_name)


if is_test_dataset:
    fixed_testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                                 download=True, transform=preprocess)
    fixed_testloader = torch.utils.data.DataLoader(fixed_testset, batch_size=batch_size,
                                                   shuffle=False)
    testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                           download=True, transform=preprocess)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                             shuffle=False)
else:
    fixed_cset1 = torchvision.datasets.CIFAR10(root='./data', train=True,
                                               download=True, transform=preprocess)
    fixed_cset2 = torchvision.datasets.CIFAR10(root='./data', train=False,
                                               download=True, transform=preprocess)
    fixed_testset = torch.utils.data.ConcatDataset([fixed_cset1, fixed_cset2])

    fixed_testloader = torch.utils.data.DataLoader(fixed_testset, batch_size=batch_size,
                                                   shuffle=False)

    cset1 = torchvision.datasets.CIFAR10(root='./data', train=True,
                                         download=True, transform=preprocess)
    cset2 = torchvision.datasets.CIFAR10(root='./data', train=False,
                                         download=True, transform=preprocess)
    testset = torch.utils.data.ConcatDataset([cset1, cset2])

    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                             shuffle=False)

print("dataset_length:", len(testset))
if is_test_dataset:
    num_classes = len(fixed_testloader.dataset.classes)
else:
    num_classes = len(cset1.classes)
model = CustomCLIP(clip_model, num_classes, n_ctx=n_ctx)

for name, param in model.named_parameters():
    if "prompt_learner" not in name:
        param.requires_grad_(False)

model.to(device)

# device_count = torch.cuda.device_count()
# if device_count > 1:
#     print(
#         f"Multiple GPUs detected (n_gpus={device_count}), use all of them!")
#     model = nn.DataParallel(model)

print('done')

criterion = F.cross_entropy
# optimizer = torch.optim.SGD(
#     model.parameters(),
#     lr=lr,
#     momentum=0.9,
#     weight_decay=5e-4,
#     dampening=0,
#     nesterov=False,
# )
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=lr,
    weight_decay=5e-4,
    betas=(0.9, 0.999),
)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, float(10)
)
scheduler = ConstantWarmupScheduler(
    optimizer, lr_scheduler, 1,
    1e-5
)
if not scheduler_operate:
    scheduler = ConstantWarmupScheduler(
        optimizer, lr_scheduler, 1,
        lr
    )
# initialization
# clip_model.to(device)
# with torch.no_grad():
#     first_centroids, label, acc = base_kmeans_model_evaluation(
#         clip_model, shortloader, num_classes)

# testloader label update with k-mean clsuter result

# shortset.targets = label
# trainloader = torch.utils.data.DataLoader(shortset, batch_size=batch_size,
#                                           shuffle=True)

train_cluster = np.load('../npy_folder/train_cluster.npy')
test_cluster = np.load('../npy_folder/test_cluster.npy')
concat_cluster = np.load('../npy_folder/concat_cluster.npy')
if is_test_dataset:
    testset.targets = test_cluster.tolist()
else:
    cset1.targets = concat_cluster[:len(cset1)].tolist()
    cset2.targets = concat_cluster[len(cset1):].tolist()
    testset = torch.utils.data.ConcatDataset([cset1, cset2])

testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=True)


# real_testset = torchvision.datasets.CIFAR10(root='./data', train=False,
#                                             download=True, transform=preprocess)

# testloader = torch.utils.data.DataLoader(
#     real_testset, batch_size=batch_size, shuffle=False)

total_epoch = 200
sm = nn.Softmax(dim=1)
for epoch in range(total_epoch):
    for dpoch in range(total_dpoch):
        score = 0
        total_loss = 0
        print('==================================================================')
        print('dpoch:', dpoch + total_dpoch * epoch)
        for i, data in enumerate(testloader, 0):
            inputs, targets = data
            inputs, targets = inputs.to(device), targets.to(device)
            output = model(inputs)
            loss = criterion(output, targets)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            pred = torch.argmax(output, dim=1)
            score += torch.sum(pred == targets)
            total_loss += loss.item()
            if i % 50 == 49:
                print('train_iter:', i, '/', len(testloader))
                print('target:',targets[0])
                print("output:",output[0])
                print("softmax_output:",sm(output)[0])
                print("accuracy:",score/(i*batch_size))
        print("train_accuracy: ", score/len(testloader.dataset))

    with torch.no_grad():
        model.eval()

        prompts = model.prompt_learner()
        tokenized_prompts = model.tokenized_prompts
        text_centroids = model.text_encoder(
            prompts, tokenized_prompts)
        # no normalized
        if cosine_sim:
            knn = cosine_kmeans_with_init
        else:
            knn = kmeans_with_init
        new_label, acc, nmi = knn(
            model, fixed_testloader, num_classes, text_centroids)
        print("val_acc", acc)
        print("val_nmi", nmi)

        model.train()
# new cluster assignments
    if is_test_dataset:
        testset.targets = new_label.tolist()
        testloader = torch.utils.data.DataLoader(
            testset, batch_size=batch_size, shuffle=True)
    else:
        cset1.targets = new_label[:len(cset1)].tolist()
        cset2.targets = new_label[len(cset1):].tolist()
        testset = torch.utils.data.ConcatDataset([cset1, cset2])
        testloader = torch.utils.data.DataLoader(
            testset, batch_size=batch_size, shuffle=True)
# model reinitialization
    model = CustomCLIP(clip_model, num_classes, n_ctx=n_ctx)

    for name, param in model.named_parameters():
        if "prompt_learner" not in name:
            param.requires_grad_(False)

    model.to(device)

    # optimizer = torch.optim.SGD(
    #     model.parameters(),
    #     lr=lr,
    #     momentum=0.9,
    #     weight_decay=5e-4,
    #     dampening=0,
    #     nesterov=False,
    # )
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=lr,
        weight_decay=5e-4,
        betas=(0.9, 0.999),
    )
    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, float(10)
    )
    scheduler = ConstantWarmupScheduler(
        optimizer, lr_scheduler, 1,
        1e-5
    )
    if not scheduler_operate:
        scheduler = ConstantWarmupScheduler(
            optimizer, lr_scheduler, 1,
            lr
        )
# Out:
# ['RN50', 'RN101', 'RN50x4', 'RN50x16', 'RN50x64', 'ViT-B/32', 'ViT-B/16', 'ViT-L/14']
# Device: cuda
# Current cuda device: 0
# Count of using GPUs: 4
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# dataset_length: 60000
# Initializing class-specific contexts
# Initial context: "X X X X X X X X X X X X X X X X"
# Number of context words (tokens): 16
# done
# ==================================================================
# dpoch: 0
# train_iter: 49 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([5.1004e-06, 5.2345e-05, 3.3932e-04, 1.0942e-04, 2.2136e-05, 9.4139e-04,
#         9.9570e-01, 1.5703e-04, 1.0682e-05, 2.6593e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.0855, 0.2311, 0.0854, 0.0854,
#         0.0856], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.7735, device='cuda:0')
# train_iter: 99 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([2.5734e-05, 1.8256e-05, 1.5805e-07, 4.7644e-07, 4.4508e-07, 9.9995e-01,
#         6.3485e-07, 2.6612e-07, 3.4418e-08, 1.8195e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.8497, device='cuda:0')
# train_iter: 149 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([9.4290e-03, 2.3156e-03, 1.3515e-03, 1.5593e-04, 7.2519e-04, 8.0659e-01,
#         1.7915e-01, 7.9423e-05, 3.8409e-06, 1.9328e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0882, 0.0875, 0.0874, 0.0873, 0.0874, 0.1956, 0.1045, 0.0873, 0.0873,
#         0.0873], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.8894, device='cuda:0')
# train_iter: 199 / 1200
# target: tensor(9, device='cuda:0')
# output: tensor([5.6545e-06, 1.3077e-07, 5.4836e-10, 1.8829e-08, 2.3793e-08, 3.0514e-07,
#         9.1944e-09, 1.1325e-08, 9.3221e-08, 9.9999e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.2320], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9098, device='cuda:0')
# train_iter: 249 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([3.9332e-07, 4.9757e-03, 1.9238e-06, 9.9407e-01, 2.7438e-05, 7.1158e-04,
#         7.3924e-06, 1.0606e-08, 2.6826e-05, 1.7999e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0858, 0.0854, 0.2308, 0.0854, 0.0855, 0.0854, 0.0854, 0.0854,
#         0.0854], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9218, device='cuda:0')
# train_iter: 299 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([5.5115e-05, 1.9789e-06, 5.1158e-06, 5.4140e-08, 3.3550e-06, 9.9993e-01,
#         2.6031e-06, 9.8969e-11, 2.0802e-06, 2.3972e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9292, device='cuda:0')
# train_iter: 349 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([9.6094e-08, 6.8144e-05, 1.2909e-07, 8.0935e-07, 9.9991e-01, 7.4132e-09,
#         3.5332e-08, 6.5470e-06, 5.1212e-08, 1.2165e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9356, device='cuda:0')
# train_iter: 399 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([4.9472e-01, 1.0817e-06, 9.5903e-07, 2.0856e-06, 8.7558e-07, 3.5397e-04,
#         1.4911e-06, 3.3364e-05, 5.0489e-01, 4.8041e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.1452, 0.0885, 0.0885, 0.0885, 0.0885, 0.0885, 0.0885, 0.0885, 0.1467,
#         0.0885], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9399, device='cuda:0')
# train_iter: 449 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([6.1998e-07, 7.4821e-10, 1.3656e-10, 1.2687e-10, 4.8452e-11, 1.2731e-06,
#         6.1518e-09, 4.9133e-06, 9.9999e-01, 2.7022e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9440, device='cuda:0')
# train_iter: 499 / 1200
# target: tensor(0, device='cuda:0')
# output: tensor([9.4172e-01, 3.2529e-06, 3.0793e-05, 9.3971e-04, 3.2372e-04, 1.0055e-04,
#         2.3020e-04, 5.1189e-04, 5.4601e-02, 1.5398e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.2206, 0.0860, 0.0860, 0.0861, 0.0861, 0.0860, 0.0860, 0.0861, 0.0909,
#         0.0862], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9476, device='cuda:0')
# train_iter: 549 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([5.5930e-02, 3.3354e-05, 3.8270e-03, 1.9843e-05, 2.5840e-04, 6.2702e-01,
#         1.5635e-01, 1.5440e-01, 1.2574e-03, 9.0622e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0938, 0.0887, 0.0891, 0.0887, 0.0887, 0.1661, 0.1037, 0.1035, 0.0888,
#         0.0888], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9498, device='cuda:0')
# train_iter: 599 / 1200
# target: tensor(0, device='cuda:0')
# output: tensor([1.0000e+00, 1.0633e-06, 2.4042e-07, 4.0816e-08, 2.6491e-08, 3.7446e-08,
#         3.3925e-08, 3.4771e-08, 2.1272e-08, 1.9119e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9525, device='cuda:0')
# train_iter: 649 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([2.0954e-07, 5.0679e-07, 2.9516e-08, 7.4853e-09, 3.3115e-08, 7.7239e-08,
#         1.0000e+00, 7.9466e-08, 1.5703e-07, 9.3872e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9542, device='cuda:0')
# train_iter: 699 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([3.5422e-07, 2.6589e-06, 4.7842e-09, 1.5634e-08, 5.0920e-08, 7.4085e-08,
#         1.0000e+00, 1.7900e-07, 1.5277e-07, 8.5405e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9558, device='cuda:0')
# train_iter: 749 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([6.8874e-07, 6.7326e-07, 6.5797e-07, 1.8739e-08, 8.4736e-08, 1.0000e+00,
#         1.5415e-07, 8.0040e-09, 3.1923e-07, 1.2203e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9576, device='cuda:0')
# train_iter: 799 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([1.6467e-05, 5.7273e-08, 1.2211e-07, 9.9998e-01, 2.3714e-07, 6.9323e-09,
#         2.4499e-08, 9.3800e-07, 8.1248e-09, 2.4324e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9586, device='cuda:0')
# train_iter: 849 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([6.8538e-06, 3.0178e-05, 7.7440e-08, 9.9987e-01, 4.7130e-05, 1.8258e-05,
#         3.3981e-07, 1.8127e-05, 5.6279e-08, 6.0920e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.2319, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9599, device='cuda:0')
# train_iter: 899 / 1200
# target: tensor(9, device='cuda:0')
# output: tensor([2.2184e-04, 2.0207e-05, 1.8856e-05, 7.4577e-06, 1.1355e-05, 8.0612e-04,
#         5.0844e-07, 2.5320e-06, 3.7843e-05, 9.9887e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.0854,
#         0.2317], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9612, device='cuda:0')
# train_iter: 949 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([7.2596e-04, 3.2882e-06, 4.7790e-07, 9.8052e-07, 6.2542e-08, 6.9473e-06,
#         9.9924e-01, 1.5455e-06, 7.8110e-06, 1.1444e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2318, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9621, device='cuda:0')
# train_iter: 999 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([3.2096e-07, 7.9622e-11, 1.6818e-11, 5.9128e-12, 7.2966e-10, 4.3160e-09,
#         2.7970e-08, 5.6332e-10, 1.0000e+00, 5.8799e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9629, device='cuda:0')
# train_iter: 1049 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([8.4624e-09, 1.4496e-08, 1.8158e-12, 1.0632e-10, 2.7014e-10, 4.5589e-06,
#         2.4862e-09, 6.1319e-11, 1.0000e+00, 1.2847e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9638, device='cuda:0')
# train_iter: 1099 / 1200
# target: tensor(0, device='cuda:0')
# output: tensor([9.9958e-01, 8.6015e-05, 1.0294e-06, 6.5422e-06, 6.7842e-05, 4.9713e-05,
#         3.2183e-05, 1.0574e-04, 1.1480e-06, 6.8891e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.2319, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0854, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9643, device='cuda:0')
# train_iter: 1149 / 1200
# target: tensor(2, device='cuda:0')
# output: tensor([3.1218e-04, 2.7320e-06, 9.9965e-01, 1.5248e-08, 1.3796e-06, 3.3809e-06,
#         4.2442e-07, 1.3731e-06, 1.9265e-08, 2.4133e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0853, 0.2319, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9650, device='cuda:0')
# train_iter: 1199 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([1.9677e-06, 2.8426e-04, 6.2433e-07, 1.2093e-06, 2.0598e-06, 1.5583e-02,
#         9.8358e-01, 4.7572e-04, 2.8591e-06, 6.3838e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0855, 0.0856, 0.0855, 0.0855, 0.0855, 0.0869, 0.2287, 0.0856, 0.0855,
#         0.0855], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9654, device='cuda:0')
# train_accuracy:  tensor(0.9646, device='cuda:0')
# ==================================================================
# dpoch: 1
# train_iter: 49 / 1200
# target: tensor(9, device='cuda:0')
# output: tensor([7.0567e-04, 5.2887e-04, 1.1090e-05, 3.8230e-01, 1.1096e-03, 4.4929e-04,
#         7.5673e-06, 3.0524e-05, 7.6915e-06, 6.1485e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0884, 0.0884, 0.0884, 0.1295, 0.0885, 0.0884, 0.0884, 0.0884, 0.0884,
#         0.1634], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(1.0033, device='cuda:0')
# train_iter: 99 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([2.2651e-04, 1.1569e-03, 4.6282e-06, 8.5588e-01, 1.6910e-04, 5.3535e-04,
#         1.0366e-04, 1.8969e-04, 2.3359e-05, 1.4171e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0869, 0.0870, 0.0869, 0.2045, 0.0869, 0.0869, 0.0869, 0.0869, 0.0869,
#         0.1001], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9929, device='cuda:0')
# train_iter: 149 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([2.8952e-08, 1.0000e+00, 1.3131e-07, 1.8578e-07, 1.0765e-06, 3.7713e-07,
#         2.0661e-06, 2.3678e-07, 4.3117e-08, 1.7338e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9902, device='cuda:0')
# train_iter: 199 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([1.8036e-08, 2.4492e-08, 5.5222e-11, 4.0910e-10, 3.2925e-09, 7.9511e-09,
#         7.1493e-10, 9.0849e-09, 1.0000e+00, 8.2080e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9867, device='cuda:0')
# train_iter: 249 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([2.1555e-07, 9.9997e-01, 1.0701e-07, 5.5085e-06, 3.7457e-07, 2.0502e-06,
#         1.7612e-05, 1.3850e-06, 1.9515e-06, 5.0495e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9853, device='cuda:0')
# train_iter: 299 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([1.5066e-07, 1.0282e-07, 2.7731e-10, 1.4304e-08, 7.2564e-10, 2.3343e-08,
#         1.0000e+00, 3.3364e-06, 3.2878e-09, 1.5945e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9844, device='cuda:0')
# train_iter: 349 / 1200
# target: tensor(9, device='cuda:0')
# output: tensor([3.3994e-04, 1.8650e-06, 1.4226e-06, 1.9074e-05, 4.4159e-06, 6.0551e-07,
#         2.5310e-07, 2.5381e-05, 1.0304e-07, 9.9961e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.2319], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9841, device='cuda:0')
# train_iter: 399 / 1200
# target: tensor(7, device='cuda:0')
# output: tensor([8.3485e-07, 3.4359e-07, 5.4705e-08, 9.7973e-07, 2.1267e-07, 8.9046e-07,
#         4.1171e-08, 1.0000e+00, 3.1707e-07, 3.3381e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9835, device='cuda:0')
# train_iter: 449 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([9.3395e-07, 9.9983e-01, 1.3746e-06, 6.3947e-06, 5.7020e-06, 2.2485e-05,
#         6.4502e-05, 3.7069e-05, 4.2533e-07, 3.1718e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.2319, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9833, device='cuda:0')
# train_iter: 499 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([4.6969e-07, 2.3091e-08, 3.6742e-08, 4.0110e-08, 1.5378e-08, 1.0000e+00,
#         2.3607e-08, 1.2854e-07, 2.6636e-07, 5.6591e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9830, device='cuda:0')
# train_iter: 549 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([6.2920e-10, 4.2545e-07, 3.4057e-08, 5.7968e-09, 1.7880e-09, 1.3622e-08,
#         1.0000e+00, 1.7446e-07, 7.5653e-10, 1.7822e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9826, device='cuda:0')
# train_iter: 599 / 1200
# target: tensor(0, device='cuda:0')
# output: tensor([9.9995e-01, 1.4702e-08, 1.6905e-07, 4.0391e-09, 2.8051e-07, 4.3473e-05,
#         1.2524e-08, 2.4953e-08, 1.2327e-06, 5.8000e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9825, device='cuda:0')
# train_iter: 649 / 1200
# target: tensor(0, device='cuda:0')
# output: tensor([9.9998e-01, 2.6346e-07, 4.9539e-08, 1.6319e-07, 7.4886e-07, 1.7454e-05,
#         1.1729e-06, 9.0340e-07, 9.1802e-09, 1.0441e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9825, device='cuda:0')
# train_iter: 699 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([8.6234e-08, 2.7613e-05, 1.3156e-07, 2.6228e-07, 3.5087e-05, 5.4136e-05,
#         1.4105e-06, 9.2330e-06, 9.9987e-01, 5.1545e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2319,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9827, device='cuda:0')
# train_iter: 749 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([7.7346e-07, 6.3114e-06, 8.1399e-08, 4.1193e-07, 9.9989e-01, 1.4434e-07,
#         4.9110e-07, 8.2578e-08, 2.6273e-11, 9.9290e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.2319, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9824, device='cuda:0')
# train_iter: 799 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([6.2291e-10, 5.1121e-07, 4.3081e-06, 5.4886e-07, 9.9999e-01, 1.8499e-07,
#         1.3022e-08, 5.3423e-08, 7.9497e-10, 1.2409e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9824, device='cuda:0')
# train_iter: 849 / 1200
# target: tensor(7, device='cuda:0')
# output: tensor([2.1200e-04, 1.5198e-05, 3.1286e-05, 8.2512e-06, 5.7196e-07, 6.3433e-04,
#         1.8587e-04, 9.9890e-01, 1.0033e-06, 1.1380e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.2318, 0.0854,
#         0.0854], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9824, device='cuda:0')
# train_iter: 899 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([2.8707e-03, 1.0320e-06, 2.1770e-06, 2.3225e-07, 6.6358e-07, 3.1628e-04,
#         3.2766e-05, 8.4168e-04, 9.9592e-01, 1.4896e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0856, 0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.0855, 0.2312,
#         0.0854], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9827, device='cuda:0')
# train_iter: 949 / 1200
# target: tensor(7, device='cuda:0')
# output: tensor([1.5188e-07, 3.0578e-08, 6.7624e-08, 3.0738e-08, 1.7715e-08, 4.9086e-08,
#         2.5242e-06, 1.0000e+00, 3.8854e-08, 7.8467e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9826, device='cuda:0')
# train_iter: 999 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([8.3525e-05, 8.0535e-04, 3.4494e-07, 9.9800e-01, 2.7495e-05, 1.0523e-03,
#         5.9662e-06, 1.0905e-05, 1.0579e-06, 9.5428e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0854, 0.0854, 0.2316, 0.0854, 0.0855, 0.0854, 0.0854, 0.0854,
#         0.0854], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9825, device='cuda:0')
# train_iter: 1049 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([5.1260e-06, 4.2092e-06, 5.6265e-01, 7.1597e-06, 1.0056e-04, 4.3717e-01,
#         1.6427e-07, 2.5763e-06, 1.4486e-08, 6.0117e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0885, 0.0885, 0.1553, 0.0885, 0.0885, 0.1370, 0.0885, 0.0885, 0.0885,
#         0.0885], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9823, device='cuda:0')
# train_iter: 1099 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([3.5149e-04, 1.6197e-04, 2.6433e-06, 6.1665e-04, 8.3320e-05, 6.8202e-03,
#         5.8098e-05, 1.2784e-03, 9.9060e-01, 2.7927e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0855, 0.0855, 0.0855, 0.0855, 0.0855, 0.0860, 0.0855, 0.0856, 0.2301,
#         0.0855], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9822, device='cuda:0')
# train_iter: 1149 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([1.8976e-06, 6.7130e-08, 3.6637e-07, 1.5804e-07, 7.1232e-08, 1.0000e+00,
#         2.1858e-09, 4.1612e-10, 2.8984e-09, 8.2784e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9822, device='cuda:0')
# train_iter: 1199 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([1.1104e-05, 1.1527e-06, 2.1976e-06, 1.1755e-06, 2.3982e-08, 9.9854e-01,
#         1.4547e-07, 1.0558e-03, 3.9058e-04, 1.1345e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.2317, 0.0854, 0.0854, 0.0854,
#         0.0854], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9822, device='cuda:0')
# train_accuracy:  tensor(0.9814, device='cuda:0')
# ==================================================================
# dpoch: 2
# train_iter: 49 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([2.1453e-09, 2.2167e-08, 2.5534e-09, 2.8392e-09, 2.9166e-10, 1.0000e+00,
#         2.0739e-10, 7.5723e-10, 7.4017e-08, 4.8483e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(1.0024, device='cuda:0')
# train_iter: 99 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([4.4160e-07, 9.9627e-01, 1.5543e-06, 2.1472e-04, 2.9040e-03, 5.0751e-04,
#         7.0781e-05, 8.2462e-06, 6.8971e-08, 2.1125e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.2312, 0.0854, 0.0854, 0.0856, 0.0854, 0.0854, 0.0854, 0.0854,
#         0.0854], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9923, device='cuda:0')
# train_iter: 149 / 1200
# target: tensor(9, device='cuda:0')
# output: tensor([5.0062e-06, 4.4865e-05, 8.9798e-06, 2.4990e-05, 5.9800e-03, 4.8961e-06,
#         1.9426e-05, 1.1636e-06, 4.0723e-06, 9.9391e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0854, 0.0854, 0.0854, 0.0859, 0.0854, 0.0854, 0.0854, 0.0854,
#         0.2308], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9897, device='cuda:0')
# train_iter: 199 / 1200
# target: tensor(0, device='cuda:0')
# output: tensor([9.9994e-01, 2.2876e-05, 4.1109e-07, 1.2418e-06, 3.6927e-06, 2.7927e-05,
#         1.8744e-07, 1.6605e-06, 6.5314e-07, 2.0790e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9878, device='cuda:0')
# train_iter: 249 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([1.0755e-07, 2.7602e-07, 3.4967e-08, 1.7529e-07, 1.4607e-08, 1.0000e+00,
#         1.1723e-10, 2.2900e-09, 3.3738e-09, 1.8115e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9865, device='cuda:0')
# train_iter: 299 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([3.9667e-06, 3.5485e-08, 3.7083e-08, 2.4782e-09, 6.3588e-07, 1.9693e-04,
#         7.0953e-06, 6.2374e-05, 9.9973e-01, 1.4511e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0854, 0.0853, 0.0853, 0.2319,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9863, device='cuda:0')
# train_iter: 349 / 1200
# target: tensor(7, device='cuda:0')
# output: tensor([3.1774e-05, 2.5468e-09, 3.6922e-08, 8.6929e-07, 2.4102e-07, 1.0587e-07,
#         1.2168e-07, 9.9996e-01, 3.7968e-06, 5.7011e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9859, device='cuda:0')
# train_iter: 399 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([2.5507e-08, 2.2996e-07, 1.9051e-08, 6.7462e-09, 1.3044e-08, 3.2458e-09,
#         1.0000e+00, 1.1586e-06, 8.7201e-07, 3.7804e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9863, device='cuda:0')
# train_iter: 449 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([2.6114e-05, 1.3762e-05, 2.5244e-04, 6.2473e-07, 2.8609e-04, 1.0645e-04,
#         9.9929e-01, 2.7226e-06, 8.9138e-07, 1.7392e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0854, 0.0853, 0.0854, 0.0854, 0.2318, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9861, device='cuda:0')
# train_iter: 499 / 1200
# target: tensor(7, device='cuda:0')
# output: tensor([7.2940e-09, 5.3841e-09, 1.1407e-07, 4.2314e-08, 8.7251e-09, 1.2146e-08,
#         3.4715e-08, 1.0000e+00, 1.2523e-07, 3.6294e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9860, device='cuda:0')
# train_iter: 549 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([2.5757e-05, 3.6159e-05, 5.5970e-04, 4.5780e-06, 6.3465e-04, 1.1588e-04,
#         7.0748e-01, 2.9113e-01, 9.5583e-06, 6.2093e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0880, 0.0880, 0.0880, 0.0880, 0.0880, 0.0880, 0.1785, 0.1177, 0.0880,
#         0.0880], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9852, device='cuda:0')
# train_iter: 599 / 1200
# target: tensor(7, device='cuda:0')
# output: tensor([3.9458e-07, 7.8529e-08, 2.5189e-08, 6.1714e-09, 2.4645e-09, 1.9241e-09,
#         3.6263e-08, 1.0000e+00, 8.4348e-08, 5.7497e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9853, device='cuda:0')
# train_iter: 649 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([1.4648e-05, 1.0921e-06, 3.2949e-07, 9.9997e-01, 2.4219e-06, 5.1810e-06,
#         6.1417e-07, 5.3717e-07, 8.0921e-09, 1.9119e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9856, device='cuda:0')
# train_iter: 699 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([7.8640e-08, 9.9996e-01, 1.4323e-06, 7.7508e-06, 6.3553e-07, 2.5298e-05,
#         1.3739e-07, 1.6989e-06, 1.4229e-07, 3.5547e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9855, device='cuda:0')
# train_iter: 749 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([1.0289e-08, 1.7852e-07, 1.2071e-08, 1.3538e-08, 8.8433e-09, 9.1869e-09,
#         1.0000e+00, 1.1943e-07, 8.5989e-08, 5.8636e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9854, device='cuda:0')
# train_iter: 799 / 1200
# target: tensor(9, device='cuda:0')
# output: tensor([6.9779e-06, 9.5252e-08, 6.6879e-08, 4.1205e-07, 6.3832e-07, 2.7449e-05,
#         9.4833e-08, 1.4069e-07, 5.4517e-09, 9.9996e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.2320], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9854, device='cuda:0')
# train_iter: 849 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([1.0422e-08, 6.1985e-09, 1.9306e-08, 5.6460e-09, 1.0000e+00, 5.1692e-08,
#         2.9106e-08, 1.5209e-08, 1.0851e-09, 1.4662e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9854, device='cuda:0')
# train_iter: 899 / 1200
# target: tensor(2, device='cuda:0')
# output: tensor([4.9042e-09, 4.7689e-09, 1.0000e+00, 1.9204e-10, 1.8337e-09, 1.4855e-07,
#         2.5771e-09, 3.9547e-10, 1.8168e-11, 5.7687e-11], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9855, device='cuda:0')
# train_iter: 949 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([1.4172e-08, 1.2524e-08, 6.3816e-10, 9.9997e-01, 1.1487e-06, 1.1412e-08,
#         5.8240e-09, 1.8254e-08, 1.1236e-08, 2.5494e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9852, device='cuda:0')
# train_iter: 999 / 1200
# target: tensor(0, device='cuda:0')
# output: tensor([9.9998e-01, 1.8869e-06, 2.0271e-07, 3.1174e-08, 2.4773e-07, 1.2782e-05,
#         3.3347e-07, 2.9715e-06, 3.4625e-07, 9.8364e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9851, device='cuda:0')
# train_iter: 1049 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([1.1545e-05, 2.1131e-05, 5.0518e-07, 1.5684e-06, 7.0312e-07, 9.9996e-01,
#         1.4657e-06, 1.5035e-08, 2.8503e-06, 3.2285e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9849, device='cuda:0')
# train_iter: 1099 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([1.4738e-08, 1.0000e+00, 2.7348e-08, 3.2394e-08, 1.0380e-08, 4.6241e-08,
#         6.6955e-10, 9.2308e-10, 2.5455e-10, 9.9429e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9846, device='cuda:0')
# train_iter: 1149 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([9.6305e-06, 9.9992e-01, 7.6712e-06, 1.7905e-05, 7.2969e-07, 5.9639e-06,
#         3.9198e-06, 2.8890e-05, 5.2502e-07, 9.1474e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9845, device='cuda:0')
# train_iter: 1199 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([1.0203e-06, 1.1080e-04, 6.3238e-08, 9.9970e-01, 1.0642e-05, 1.6258e-07,
#         3.7727e-08, 1.6353e-06, 1.6017e-09, 1.7388e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.2319, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0854], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9845, device='cuda:0')
# train_accuracy:  tensor(0.9837, device='cuda:0')
# ==================================================================
# dpoch: 3
# train_iter: 49 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([1.3814e-07, 1.0671e-07, 7.6465e-08, 2.9695e-07, 1.0000e+00, 6.0484e-08,
#         9.5792e-08, 6.1462e-08, 1.1756e-10, 3.0961e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(1.0057, device='cuda:0')
# train_iter: 99 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([3.6941e-05, 1.1950e-06, 8.3964e-09, 9.8973e-01, 5.2766e-08, 5.3493e-07,
#         6.0587e-07, 2.8990e-08, 1.6409e-06, 1.0229e-02], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0855, 0.0855, 0.0855, 0.2299, 0.0855, 0.0855, 0.0855, 0.0855, 0.0855,
#         0.0863], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9925, device='cuda:0')
# train_iter: 149 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([2.4446e-07, 5.2080e-07, 2.0126e-08, 9.9999e-01, 3.8294e-06, 3.4222e-06,
#         2.1166e-07, 3.8168e-07, 7.4207e-09, 1.1239e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9909, device='cuda:0')
# train_iter: 199 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([2.7139e-09, 1.1690e-07, 9.3567e-09, 1.3542e-08, 5.8398e-09, 1.0000e+00,
#         3.9392e-10, 1.7402e-09, 7.5373e-09, 2.3095e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9885, device='cuda:0')
# train_iter: 249 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([1.4051e-07, 1.7931e-07, 3.5805e-07, 2.3062e-07, 3.1383e-08, 1.0000e+00,
#         1.3694e-09, 3.7885e-08, 2.9344e-08, 1.8990e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9874, device='cuda:0')
# train_iter: 299 / 1200
# target: tensor(9, device='cuda:0')
# output: tensor([5.4539e-07, 1.4055e-06, 4.2478e-08, 1.5851e-07, 9.1818e-07, 3.4991e-07,
#         3.0201e-07, 5.7953e-09, 6.3095e-08, 1.0000e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.2320], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9876, device='cuda:0')
# train_iter: 349 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([5.8526e-08, 1.0000e+00, 5.9556e-08, 6.2308e-08, 9.3872e-10, 6.6684e-10,
#         9.4017e-07, 5.4660e-09, 1.7019e-09, 1.1922e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9876, device='cuda:0')
# train_iter: 399 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([3.2653e-07, 5.4992e-07, 7.5828e-08, 3.5801e-08, 1.8444e-07, 1.0000e+00,
#         7.0781e-07, 1.4636e-08, 2.3184e-09, 3.6621e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9866, device='cuda:0')
# train_iter: 449 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([8.8225e-06, 2.7357e-07, 2.9983e-08, 3.7310e-08, 5.4629e-07, 9.6564e-02,
#         2.8159e-06, 1.4753e-06, 9.0342e-01, 1.1729e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0864, 0.0864, 0.0864, 0.0864, 0.0864, 0.0952, 0.0864, 0.0864, 0.2133,
#         0.0864], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9863, device='cuda:0')
# train_iter: 499 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([1.4113e-07, 9.8562e-01, 4.0875e-07, 2.2387e-06, 1.3792e-02, 5.5632e-04,
#         6.0878e-07, 1.6582e-06, 1.3525e-06, 2.4681e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0855, 0.2291, 0.0855, 0.0855, 0.0867, 0.0856, 0.0855, 0.0855, 0.0855,
#         0.0855], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9859, device='cuda:0')
# train_iter: 549 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([2.2940e-08, 5.5041e-06, 1.3337e-08, 3.7276e-08, 6.9156e-08, 2.3144e-07,
#         9.9999e-01, 6.7924e-06, 1.0154e-08, 4.0625e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9860, device='cuda:0')
# train_iter: 599 / 1200
# target: tensor(7, device='cuda:0')
# output: tensor([3.7563e-06, 1.0884e-06, 1.4090e-08, 7.0725e-08, 2.4603e-08, 2.9532e-07,
#         3.7204e-07, 9.9999e-01, 3.3958e-07, 2.4480e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9861, device='cuda:0')
# train_iter: 649 / 1200
# target: tensor(0, device='cuda:0')
# output: tensor([9.9959e-01, 2.7807e-05, 2.8145e-07, 2.8900e-04, 1.8580e-06, 4.1447e-05,
#         1.1275e-05, 2.0607e-05, 9.1163e-06, 1.2391e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.2319, 0.0853, 0.0853, 0.0854, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9862, device='cuda:0')
# train_iter: 699 / 1200
# target: tensor(2, device='cuda:0')
# output: tensor([2.7755e-06, 4.3247e-06, 9.9983e-01, 3.3723e-08, 6.2386e-07, 2.0305e-07,
#         1.2850e-06, 1.5957e-04, 5.7021e-10, 4.5273e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.2319, 0.0853, 0.0853, 0.0853, 0.0853, 0.0854, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9861, device='cuda:0')
# train_iter: 749 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([1.4327e-10, 7.6293e-10, 5.3362e-09, 2.7977e-07, 1.0000e+00, 4.7915e-09,
#         7.5303e-10, 1.0849e-09, 6.3863e-10, 3.7297e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9860, device='cuda:0')
# train_iter: 799 / 1200
# target: tensor(9, device='cuda:0')
# output: tensor([2.3450e-05, 2.3401e-04, 3.2733e-06, 1.5489e-06, 1.0210e-04, 3.1936e-07,
#         1.0242e-06, 1.2082e-08, 3.3603e-07, 9.9963e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0854, 0.0853, 0.0853, 0.0854, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.2319], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9858, device='cuda:0')
# train_iter: 849 / 1200
# target: tensor(7, device='cuda:0')
# output: tensor([1.5585e-08, 2.0794e-08, 1.0618e-07, 3.6430e-08, 3.7293e-09, 7.5018e-07,
#         3.3444e-05, 9.9997e-01, 5.6124e-08, 3.2352e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9857, device='cuda:0')
# train_iter: 899 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([2.1011e-09, 8.9563e-11, 3.4726e-14, 1.2183e-12, 6.9011e-11, 1.1775e-10,
#         6.6894e-11, 5.6314e-11, 1.0000e+00, 9.6530e-11], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9856, device='cuda:0')
# train_iter: 949 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([3.6513e-07, 7.8939e-07, 4.4098e-08, 8.1418e-08, 4.8027e-09, 1.6952e-08,
#         1.0000e+00, 7.2853e-07, 1.3942e-08, 8.0013e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9855, device='cuda:0')
# train_iter: 999 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([1.8081e-07, 2.1546e-08, 6.0442e-09, 9.2175e-10, 9.4908e-09, 1.0000e+00,
#         1.1044e-09, 4.3306e-10, 9.1026e-11, 1.4459e-09], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9855, device='cuda:0')
# train_iter: 1049 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([8.0633e-10, 9.9253e-09, 1.7410e-09, 1.4281e-07, 1.0000e+00, 1.3383e-08,
#         1.2834e-09, 1.9695e-09, 5.2261e-11, 8.4051e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9855, device='cuda:0')
# train_iter: 1099 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([6.3131e-07, 9.5504e-06, 2.4311e-08, 1.3067e-06, 9.9991e-01, 2.5734e-06,
#         4.4213e-05, 3.3416e-05, 1.3675e-08, 2.4667e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9856, device='cuda:0')
# train_iter: 1149 / 1200
# target: tensor(9, device='cuda:0')
# output: tensor([3.9017e-05, 8.3453e-07, 1.4504e-08, 7.6056e-06, 5.7770e-07, 8.4755e-08,
#         3.3592e-07, 1.0348e-07, 1.1999e-07, 9.9995e-01], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.2320], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9856, device='cuda:0')
# train_iter: 1199 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([4.3757e-08, 9.7232e-11, 3.6840e-11, 3.7434e-09, 6.9036e-09, 2.6085e-10,
#         2.9376e-10, 1.8799e-09, 1.0000e+00, 2.3927e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9856, device='cuda:0')
# train_accuracy:  tensor(0.9848, device='cuda:0')
# image_ACC 0.9550333333333333
# image_NMI 0.9068926506624871
# val_acc 0.9550333333333333
# val_nmi 0.9068926506624871
# Initializing class-specific contexts
# Initial context: "X X X X X X X X X X X X X X X X"
# Number of context words (tokens): 16
# ==================================================================
# dpoch: 4
# train_iter: 49 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([2.3261e-04, 3.3518e-11, 3.9712e-05, 7.1953e-04, 8.2343e-05, 9.9856e-01,
#         8.9208e-05, 2.1583e-04, 5.6417e-05, 2.3798e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0854, 0.0854, 0.0854, 0.0854, 0.0854, 0.2317, 0.0854, 0.0854, 0.0854,
#         0.0854], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.7886, device='cuda:0')
# train_iter: 99 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([2.0098e-06, 1.0372e-12, 4.4065e-07, 2.2164e-06, 9.9999e-01, 6.2441e-07,
#         1.7253e-09, 1.3084e-07, 1.1185e-08, 5.6996e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.8321, device='cuda:0')
# train_iter: 149 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([4.6697e-05, 2.9758e-11, 7.4662e-07, 1.0230e-05, 3.4923e-06, 9.9988e-01,
#         2.4170e-07, 1.2693e-07, 3.7848e-05, 2.4059e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2319, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.8487, device='cuda:0')
# train_iter: 199 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([2.1441e-05, 9.9987e-01, 5.6468e-06, 2.4871e-05, 2.9870e-06, 3.5256e-05,
#         1.2796e-05, 6.2200e-06, 8.9662e-06, 7.1866e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.2319, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.8708, device='cuda:0')
# train_iter: 249 / 1200
# target: tensor(4, device='cuda:0')
# output: tensor([4.3424e-07, 6.9011e-04, 1.9934e-06, 2.5967e-07, 9.9930e-01, 6.9872e-08,
#         1.8019e-07, 1.8600e-06, 3.2203e-09, 3.5005e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0854, 0.0853, 0.0853, 0.2318, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.8924, device='cuda:0')
# train_iter: 299 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([4.8964e-06, 1.5598e-07, 3.2000e-07, 2.7302e-07, 2.8312e-08, 3.9257e-07,
#         9.9999e-01, 3.5086e-06, 1.5002e-07, 6.6778e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9071, device='cuda:0')
# train_iter: 349 / 1200
# target: tensor(8, device='cuda:0')
# output: tensor([7.3913e-07, 2.5361e-09, 1.0448e-10, 1.6401e-06, 3.8349e-08, 2.8791e-09,
#         2.3676e-07, 4.9500e-10, 1.0000e+00, 1.3445e-10], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9173, device='cuda:0')
# train_iter: 399 / 1200
# target: tensor(5, device='cuda:0')
# output: tensor([6.5704e-08, 2.2570e-07, 1.7350e-07, 3.7953e-07, 4.1913e-08, 1.0000e+00,
#         2.5332e-09, 1.1582e-07, 5.2047e-08, 1.5004e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9241, device='cuda:0')
# train_iter: 449 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([5.3748e-05, 9.2813e-07, 7.0517e-05, 8.1562e-05, 9.0448e-06, 1.1656e-03,
#         9.8605e-01, 1.2539e-02, 1.3750e-05, 1.2441e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0855, 0.0855, 0.0855, 0.0855, 0.0855, 0.0856, 0.2292, 0.0866, 0.0855,
#         0.0855], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9302, device='cuda:0')
# train_iter: 499 / 1200
# target: tensor(2, device='cuda:0')
# output: tensor([3.0637e-07, 1.8157e-06, 1.0000e+00, 1.3434e-08, 1.0120e-07, 2.7615e-08,
#         1.9204e-07, 3.8129e-08, 6.1474e-10, 9.0590e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9352, device='cuda:0')
# train_iter: 549 / 1200
# target: tensor(2, device='cuda:0')
# output: tensor([3.0471e-08, 2.0648e-07, 9.9999e-01, 2.2966e-07, 3.7165e-06, 8.0539e-06,
#         1.2876e-08, 4.2765e-08, 6.6409e-09, 1.5632e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9396, device='cuda:0')
# train_iter: 599 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([2.7940e-08, 1.6013e-08, 3.7142e-08, 6.3257e-08, 1.5490e-07, 7.9582e-07,
#         9.9999e-01, 5.0355e-06, 7.7275e-08, 1.3994e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9430, device='cuda:0')
# train_iter: 649 / 1200
# target: tensor(1, device='cuda:0')
# output: tensor([2.1628e-08, 1.0000e+00, 1.4555e-08, 1.5443e-07, 2.0636e-07, 2.2103e-08,
#         3.6901e-08, 3.0339e-08, 1.1314e-08, 2.1212e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9456, device='cuda:0')
# train_iter: 699 / 1200
# target: tensor(3, device='cuda:0')
# output: tensor([2.0842e-05, 9.2416e-06, 5.2015e-07, 9.9991e-01, 1.1233e-05, 3.6456e-05,
#         2.9963e-06, 9.8924e-06, 4.2318e-07, 1.7312e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9478, device='cuda:0')
# train_iter: 749 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([8.1385e-07, 3.1500e-06, 9.6458e-06, 3.9472e-06, 1.4708e-05, 7.0808e-04,
#         9.9924e-01, 1.3471e-05, 4.5688e-07, 6.2560e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0854, 0.2318, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9501, device='cuda:0')
# train_iter: 799 / 1200
# target: tensor(2, device='cuda:0')
# output: tensor([4.6790e-06, 5.0565e-07, 9.9997e-01, 1.3899e-06, 1.2732e-06, 2.0245e-05,
#         5.6209e-08, 1.3485e-07, 3.2001e-07, 6.2244e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9521, device='cuda:0')
# train_iter: 849 / 1200
# target: tensor(0, device='cuda:0')
# output: tensor([9.9998e-01, 1.7143e-07, 5.8447e-08, 1.7598e-06, 3.4474e-08, 9.1284e-06,
#         7.8220e-08, 6.4599e-07, 7.2066e-06, 1.2540e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.2320, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9539, device='cuda:0')
# train_iter: 899 / 1200
# target: tensor(6, device='cuda:0')
# output: tensor([1.2268e-09, 9.8828e-09, 2.9701e-11, 2.9698e-08, 2.3292e-10, 3.4162e-07,
#         1.0000e+00, 2.2133e-09, 1.1761e-09, 5.3351e-08], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# softmax_output: tensor([0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.0853, 0.2320, 0.0853, 0.0853,
#         0.0853], device='cuda:0', grad_fn=<SelectBackward0>)
# accuracy: tensor(0.9553, device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 157>()
#     164 inputs, targets = data
#     165 inputs, targets = inputs.to(device), targets.to(device)
# --> 166 output = model(inputs)
#     167 loss = criterion(output, targets)
#     168 optimizer.zero_grad()
#
# File ~/miniconda3/envs/kcc/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/clustering/tgc_v1/notebooks/../networks.py:119, in CustomCLIP.forward(self, image)
#     117 prompts = self.prompt_learner()
#     118 tokenized_prompts = self.tokenized_prompts
# --> 119 text_features = self.text_encoder(prompts, tokenized_prompts)
#     121 image_features = image_features / \
#     122     image_features.norm(dim=-1, keepdim=True)
#     123 text_features = text_features / \
#     124     text_features.norm(dim=-1, keepdim=True)
#
# File ~/miniconda3/envs/kcc/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/clustering/tgc_v1/notebooks/../networks.py:39, in TextEncoder.forward(self, prompts, tokenized_prompts)
#      35 x = self.ln_final(x).type(self.dtype)
#      37 # x.shape = [batch_size, n_ctx, transformer.width]
#      38 # take features from the eot embedding (eot_token is the highest number in each sequence)
# ---> 39 x = x[torch.arange(x.shape[0]), tokenized_prompts.argmax(
#      40     dim=-1)] @ self.text_projection
#      42 return x
#
# KeyboardInterrupt:

# %%
with torch.no_grad():
    model.eval()

    prompts = model.prompt_learner()
    tokenized_prompts = model.tokenized_prompts
    text_centroids = model.text_encoder(
        prompts, tokenized_prompts)

# %%
text_centroids
# Out:
# tensor([[-0.6734,  0.4417, -0.5501,  ...,  0.6089,  0.2828, -0.5241],
#         [-0.1357,  0.3524, -0.2181,  ..., -0.1356, -0.4981, -0.3242],
#         [ 0.2851, -0.0177, -0.3161,  ...,  0.2290, -0.2723, -0.5159],
#         ...,
#         [-0.3672, -0.1307, -0.0663,  ...,  0.0161,  0.3462, -0.5525],
#         [ 0.0424, -0.1261, -0.2594,  ...,  0.1181,  0.3776,  0.0690],
#         [-0.2455,  0.1425,  0.4739,  ...,  0.1930,  0.1103, -0.0168]],
#        device='cuda:0')

# %%
import numpy as np
x = np.array([9.9989e-01, 2.5081e-05, 6.0233e-07, 7.8063e-07, 5.0855e-05, 5.3249e-06,
        2.3968e-06, 1.6679e-06, 3.4923e-07, 2.1723e-05])

# %%
x = np.round(x,4)
x
# Out:
# array([9.999e-01, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e-04, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00])
